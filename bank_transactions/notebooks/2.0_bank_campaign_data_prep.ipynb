# %% [markdown]
# # **Bank transactions**
# ## Data preparation
#
# Carlos Garavito
# ***

# %%
# import packages
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# set no limit to raw display with pandas
pd.set_option('display.max_rows', None)

# define working paths
PROJECT_PATH = os.getcwd()
RAWDATA_PATH = os.path.join(PROJECT_PATH, os.pardir, 'data', 'raw')
INTERIM_PATH = os.path.join(PROJECT_PATH, os.pardir, 'data', 'interim')
PROCDATA_PATH = os.path.join(PROJECT_PATH, os.pardir, 'data', 'processed')

# %%
# read interim data
file_1 = os.path.join(INTERIM_PATH, "bank_campaign_v2.csv")
df_int_data = pd.read_csv(file_1)

# %%
df_int_data.sample(5)
# Out:
#        age          job  marital            education default housing loan  \
# 38735   72      retired  married  professional.course      no     yes   no
# 6061    37  blue-collar   single  professional.course      no     yes   no
# 7587    30  blue-collar  married             basic.6y      no      no   no
# 37330   58   technician  married  professional.course      no      no   no
# 3777    33  blue-collar  married  professional.course      no     yes   no
#
#          contact month day_of_week  duration  campaign  pdays  previous  \
# 38735  telephone   nov         wed        93         2    999         0
# 6061   telephone   may         tue       213         2    999         0
# 7587   telephone   may         fri        88         2    999         0
# 37330   cellular   aug         tue       704         2    999         0
# 3777   telephone   may         fri       208         2    999         0
#
#           poutcome  cons.conf.idx  euribor3m subscribed
# 38735  nonexistent          -30.1      0.715         no
# 6061   nonexistent          -36.4      4.857         no
# 7587   nonexistent          -36.4      4.864         no
# 37330  nonexistent          -31.4      0.883        yes
# 3777   nonexistent          -36.4      4.859         no

# %% [markdown]
# ## Imputing null values
# ***

# %% [markdown]
# There are no null values. This was checked in the [EDA notebook](#).

# %%
# identify null values by percentage
missing_values = df_int_data.isnull()
missing_values.sum() / len(df_int_data)
# Out:
# age              0.0
# job              0.0
# marital          0.0
# education        0.0
# default          0.0
# housing          0.0
# loan             0.0
# contact          0.0
# month            0.0
# day_of_week      0.0
# duration         0.0
# campaign         0.0
# pdays            0.0
# previous         0.0
# poutcome         0.0
# cons.conf.idx    0.0
# euribor3m        0.0
# subscribed       0.0
# dtype: float64

# %% [markdown]
# ## Imputing duplicated values
# ***

# %%
print(f"Data set has {len(df_int_data[df_int_data.duplicated(keep='last')])} duplicated values")
# Out:
# Data set has 12 duplicated values

# %%
# check for duplicated rows
df_int_data[df_int_data.duplicated(keep='last')]
# Out:
#        age          job   marital            education  default housing loan  \
# 1265    39  blue-collar   married             basic.6y       no      no   no
# 12260   36      retired   married              unknown       no      no   no
# 14155   27   technician    single  professional.course       no      no   no
# 16819   47   technician  divorced          high.school       no     yes   no
# 18464   32   technician    single  professional.course       no     yes   no
# 20072   55     services   married          high.school  unknown      no   no
# 20531   41   technician   married  professional.course       no     yes   no
# 25183   39       admin.   married    university.degree       no      no   no
# 28476   24     services    single          high.school       no     yes   no
# 32505   35       admin.   married    university.degree       no     yes   no
# 36950   45       admin.   married    university.degree       no      no   no
# 38255   71      retired    single    university.degree       no      no   no
#
#          contact month day_of_week  duration  campaign  pdays  previous  \
# 1265   telephone   may         thu       124         1    999         0
# 12260  telephone   jul         thu        88         1    999         0
# 14155   cellular   jul         mon       331         2    999         0
# 16819   cellular   jul         thu        43         3    999         0
# 18464   cellular   jul         thu       128         1    999         0
# 20072   cellular   aug         mon        33         1    999         0
# 20531   cellular   aug         tue       127         1    999         0
# 25183   cellular   nov         tue       123         2    999         0
# 28476   cellular   apr         tue       114         1    999         0
# 32505   cellular   may         fri       348         4    999         0
# 36950   cellular   jul         thu       252         1    999         0
# 38255  telephone   oct         tue       120         1    999         0
#
#           poutcome  cons.conf.idx  euribor3m subscribed
# 1265   nonexistent          -36.4      4.855         no
# 12260  nonexistent          -42.7      4.966         no
# 14155  nonexistent          -42.7      4.962         no
# 16819  nonexistent          -42.7      4.962         no
# 18464  nonexistent          -42.7      4.968         no
# 20072  nonexistent          -36.1      4.965         no
# 20531  nonexistent          -36.1      4.966         no
# 25183  nonexistent          -42.0      4.153         no
# 28476  nonexistent          -47.1      1.423         no
# 32505  nonexistent          -46.2      1.313         no
# 36950  nonexistent          -33.6      1.072        yes
# 38255  nonexistent          -26.9      0.742         no

# %%
# drop duplicated rows
df_int_data = df_int_data.drop_duplicates(keep='last')

# %%
print(f"Data set after duplicated values imputation, have {df_int_data.shape[0]} rows and {df_int_data.shape[1]} columns.")
# Out:
# Data set after duplicated values imputation, have 41173 rows and 18 columns.

# %% [markdown]
# ## Separating variables into features and target
# ***

# %%
target = df_int_data.subscribed
df_features = df_int_data.drop(columns=["subscribed"])

# %%
target.sample(5)
# Out:
# 15021    no
# 8508     no
# 10898    no
# 12149    no
# 20861    no
# Name: subscribed, dtype: object

# %%
df_features.sample(5)
# Out:
#        age         job   marital          education default housing loan  \
# 40816   30  technician    single  university.degree      no     yes   no
# 14959   38  management    single  university.degree      no      no   no
# 29540   50    services   married        high.school      no     yes   no
# 3189    34      admin.    single        high.school      no     yes   no
# 7150    50  technician  divorced           basic.9y      no      no  yes
#
#          contact month day_of_week  duration  campaign  pdays  previous  \
# 40816   cellular   sep         fri       173         2     15         4
# 14959  telephone   jul         wed       284         8    999         0
# 29540   cellular   apr         mon        12         6    999         0
# 3189   telephone   may         thu       168         5    999         0
# 7150   telephone   may         thu        48         5    999         0
#
#           poutcome  cons.conf.idx  euribor3m
# 40816      failure          -37.5      0.879
# 14959  nonexistent          -42.7      4.957
# 29540  nonexistent          -47.1      1.405
# 3189   nonexistent          -36.4      4.860
# 7150   nonexistent          -36.4      4.860

# %% [markdown]
# ## Data preparation
# ***

# %%
# read data
y = target
X = df_features

# %%
# replace 'yes' and 'no' values with 0 and 1
y.replace({"no":0, "yes":1}, inplace=True)
y.head(5)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: subscribed, dtype: int64

# %% [markdown]
# **Asumption 1** To avoid different dimensionality due one get_dummies method due different values on samples, one hoy encoding its performed over the whole data set, and, later the slipt will be performed.

# %%
# one hot encoding values 
X  =  pd.get_dummies(X)
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41173 entries, 0 to 41184
# Data columns (total 60 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   age                            41173 non-null  int64
#  1   duration                       41173 non-null  int64
#  2   campaign                       41173 non-null  int64
#  3   pdays                          41173 non-null  int64
#  4   previous                       41173 non-null  int64
#  5   cons.conf.idx                  41173 non-null  float64
#  6   euribor3m                      41173 non-null  float64
#  7   job_admin.                     41173 non-null  uint8
#  8   job_blue-collar                41173 non-null  uint8
#  9   job_entrepreneur               41173 non-null  uint8
#  10  job_housemaid                  41173 non-null  uint8
#  11  job_management                 41173 non-null  uint8
#  12  job_retired                    41173 non-null  uint8
#  13  job_self-employed              41173 non-null  uint8
#  14  job_services                   41173 non-null  uint8
#  15  job_student                    41173 non-null  uint8
#  16  job_technician                 41173 non-null  uint8
#  17  job_unemployed                 41173 non-null  uint8
#  18  job_unknown                    41173 non-null  uint8
#  19  marital_divorced               41173 non-null  uint8
#  20  marital_married                41173 non-null  uint8
#  21  marital_single                 41173 non-null  uint8
#  22  marital_unknown                41173 non-null  uint8
#  23  education_basic.4y             41173 non-null  uint8
#  24  education_basic.6y             41173 non-null  uint8
#  25  education_basic.9y             41173 non-null  uint8
#  26  education_high.school          41173 non-null  uint8
#  27  education_illiterate           41173 non-null  uint8
#  28  education_professional.course  41173 non-null  uint8
#  29  education_university.degree    41173 non-null  uint8
#  30  education_unknown              41173 non-null  uint8
#  31  default_no                     41173 non-null  uint8
#  32  default_unknown                41173 non-null  uint8
#  33  default_yes                    41173 non-null  uint8
#  34  housing_no                     41173 non-null  uint8
#  35  housing_unknown                41173 non-null  uint8
#  36  housing_yes                    41173 non-null  uint8
#  37  loan_no                        41173 non-null  uint8
#  38  loan_unknown                   41173 non-null  uint8
#  39  loan_yes                       41173 non-null  uint8
#  40  contact_cellular               41173 non-null  uint8
#  41  contact_telephone              41173 non-null  uint8
#  42  month_apr                      41173 non-null  uint8
#  43  month_aug                      41173 non-null  uint8
#  44  month_dec                      41173 non-null  uint8
#  45  month_jul                      41173 non-null  uint8
#  46  month_jun                      41173 non-null  uint8
#  47  month_mar                      41173 non-null  uint8
#  48  month_may                      41173 non-null  uint8
#  49  month_nov                      41173 non-null  uint8
#  50  month_oct                      41173 non-null  uint8
#  51  month_sep                      41173 non-null  uint8
#  52  day_of_week_fri                41173 non-null  uint8
#  53  day_of_week_mon                41173 non-null  uint8
#  54  day_of_week_thu                41173 non-null  uint8
#  55  day_of_week_tue                41173 non-null  uint8
#  56  day_of_week_wed                41173 non-null  uint8
#  57  poutcome_failure               41173 non-null  uint8
#  58  poutcome_nonexistent           41173 non-null  uint8
#  59  poutcome_success               41173 non-null  uint8
# dtypes: float64(2), int64(5), uint8(53)
# memory usage: 4.6 MB

# %%
# check first register - without encoding
df_features.head(1).T
# Out:
#                          0
# age                     56
# job              housemaid
# marital            married
# education         basic.4y
# default                 no
# housing                 no
# loan                    no
# contact          telephone
# month                  may
# day_of_week            mon
# duration               261
# campaign                 1
# pdays                  999
# previous                 0
# poutcome       nonexistent
# cons.conf.idx        -36.4
# euribor3m            4.857

# %%
# check first register - one hot encoding
X.head(1).T
# Out:
#                                      0
# age                             56.000
# duration                       261.000
# campaign                         1.000
# pdays                          999.000
# previous                         0.000
# cons.conf.idx                  -36.400
# euribor3m                        4.857
# job_admin.                       0.000
# job_blue-collar                  0.000
# job_entrepreneur                 0.000
# job_housemaid                    1.000
# job_management                   0.000
# job_retired                      0.000
# job_self-employed                0.000
# job_services                     0.000
# job_student                      0.000
# job_technician                   0.000
# job_unemployed                   0.000
# job_unknown                      0.000
# marital_divorced                 0.000
# marital_married                  1.000
# marital_single                   0.000
# marital_unknown                  0.000
# education_basic.4y               1.000
# education_basic.6y               0.000
# education_basic.9y               0.000
# education_high.school            0.000
# education_illiterate             0.000
# education_professional.course    0.000
# education_university.degree      0.000
# education_unknown                0.000
# default_no                       1.000
# default_unknown                  0.000
# default_yes                      0.000
# housing_no                       1.000
# housing_unknown                  0.000
# housing_yes                      0.000
# loan_no                          1.000
# loan_unknown                     0.000
# loan_yes                         0.000
# contact_cellular                 0.000
# contact_telephone                1.000
# month_apr                        0.000
# month_aug                        0.000
# month_dec                        0.000
# month_jul                        0.000
# month_jun                        0.000
# month_mar                        0.000
# month_may                        1.000
# month_nov                        0.000
# month_oct                        0.000
# month_sep                        0.000
# day_of_week_fri                  0.000
# day_of_week_mon                  1.000
# day_of_week_thu                  0.000
# day_of_week_tue                  0.000
# day_of_week_wed                  0.000
# poutcome_failure                 0.000
# poutcome_nonexistent             1.000
# poutcome_success                 0.000

# %% [markdown]
# ## Split data into train, test and validation

# %%
# split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# split into train and validation
X_train, X_CV, y_train, y_CV = train_test_split(X_train, y_train, test_size=0.3, random_state=101)

print(f"Train data set contains {len(X_train)} samples")
print(f"Test data set contains {len(X_test)} samples")
print(f"Validation data set contains {len(X_CV)} samples")
print("---")
print(f"Total samples: {len(X_train) +  len(X_test) + len(X_CV)}  ")
# Out:
# Train data set contains 20174 samples
# Test data set contains 12352 samples
# Validation data set contains 8647 samples
# ---
# Total samples: 41173

# %% [markdown]
# ## Save preparated data
# ***

# %%
# save train data
X_train.to_csv(os.path.join(PROCDATA_PATH, 'train', 'X_train.csv'), index=False)
y_train.to_csv(os.path.join(PROCDATA_PATH, 'train', 'y_train.csv'), index=False)

# save test data
X_test.to_csv(os.path.join(PROCDATA_PATH, 'test', 'X_test.csv'), index=False)
y_test.to_csv(os.path.join(PROCDATA_PATH, 'test', 'y_test.csv'), index=False)

# save validation data
X_CV.to_csv(os.path.join(PROCDATA_PATH, 'validation', 'X_CV.csv'), index=False)
y_CV.to_csv(os.path.join(PROCDATA_PATH, 'validation', 'y_CV.csv'), index=False)
